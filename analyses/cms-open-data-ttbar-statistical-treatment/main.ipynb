# %%
import ROOT
import numpy as np
from utils.agc_sample import AGC_Sample
from utils.rebinning_tool import RebinningTool
from utils.extra import MuteTool
from utils.drawer import Visualization, DrawModel
# Out:
# /home/valerii/Documents/IRIS/analysis-grand-challenge-root/analyses/cms-open-data-ttbar-statistical-treatment/utils/agc_sample.py:5: RuntimeWarning: class "RooStats::HistFactory::Sample" has no virtual destructor
#   class AGC_Sample(ROOT.RooStats.HistFactory.Sample):

# %%
MuteTool() # Mute all the messages from minimizer

# %%
rebinning_tool = RebinningTool() # Rebinning as extra step (was discussed with Jonas)
rebinning_tool.set_xmin(110)
rebinning_tool.set_rebin(2)
rebinning_tool.set_input_path("data/histograms.root")
rebinning_tool.set_output_path("data/temp_histos.root") # if you dont specify this -> overwrite (?)
rebinning_tool.apply_rebinning()

# %%
file = ROOT.TFile("data/HistFactoryExtra.root", "RECREATE") # should be hidden. Cleaning the file
file.Close() # create separate file for each file -> two much files

input_file = "data/temp_histos.root" # input file for futher defined histograms

# %%
meas = ROOT.RooStats.HistFactory.Measurement("meas", "meas")
meas.SetLumi(1.0)
meas.SetLumiRelErr(0.0)

# ! main difference
lumi_systematics = ROOT.RooStats.HistFactory.OverallSys() # we define it one time -> dont need to redefine it
lumi_systematics.SetName("Lumi")
lumi_systematics.SetLow(0.97)
lumi_systematics.SetHigh(1.03)

# %%
channel = ROOT.RooStats.HistFactory.Channel("channel_4j1b_CR")
channel.SetData("4j1b_pseudodata", input_file)
channel.SetStatErrorConfig(0.001, "Gaussian")

ttbar = AGC_Sample("ttbar", "4j1b_ttbar", input_file)
ttbar.SetSystematicsInputFile(input_file)   # if use SetInputFile -> change input file for nominal histogram 
                                            # we can put input file from sample data definition as default

ttbar.AddOverallSys(lumi_systematics)
ttbar.ActivateStatError() # ROOT does not have DisableStatError() method, so we have to keep this :(
ttbar.AddNormPlusShapeHistoSys("ME_variation",      histoname_up = "4j1b_ttbar_ME_var"                                                          ) # "histogram_up" can be skipped here
ttbar.AddNormPlusShapeHistoSys("PS_variation",      histoname_up = "4j1b_ttbar_PS_var"                                                          ) # histogram path is specified as "" in default case
ttbar.AddNormPlusShapeHistoSys("tt_scale_var",      histoname_up = "4j1b_ttbar_scaleup",        histoname_down = "4j1b_ttbar_scaledown"         )
ttbar.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j1b_ttbar_pt_scale_up"                                                     )
ttbar.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j1b_ttbar_pt_res_up"                                                       )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j1b_ttbar_btag_var_0_up",  histoname_down = "4j1b_ttbar_btag_var_0_down"   )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j1b_ttbar_btag_var_1_up",  histoname_down = "4j1b_ttbar_btag_var_1_down"   )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j1b_ttbar_btag_var_2_up",  histoname_down = "4j1b_ttbar_btag_var_2_down"   )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j1b_ttbar_btag_var_3_up",  histoname_down = "4j1b_ttbar_btag_var_3_down"   )
ttbar.AddNormFactor("ttbar_norm", 1, 0, 10)
channel.AddSample(ttbar)

wjets = AGC_Sample("wjets", "4j1b_wjets", input_file)
wjets.SetSystematicsInputFile(input_file)
wjets.ActivateStatError()
wjets.AddOverallSys(lumi_systematics)
wjets.AddNormPlusShapeHistoSys("jet_energy_scale",      histoname_up = "4j1b_wjets_pt_scale_up"                                                     )
wjets.AddNormPlusShapeHistoSys("jet_energy_res",        histoname_up = "4j1b_wjets_pt_res_up"                                                       )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_1",            histoname_up = "4j1b_wjets_btag_var_0_up",  histoname_down = "4j1b_wjets_btag_var_0_down"   )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_2",            histoname_up = "4j1b_wjets_btag_var_1_up",  histoname_down = "4j1b_wjets_btag_var_1_down"   )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_3",            histoname_up = "4j1b_wjets_btag_var_2_up",  histoname_down = "4j1b_wjets_btag_var_2_down"   )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_4",            histoname_up = "4j1b_wjets_btag_var_3_up",  histoname_down = "4j1b_wjets_btag_var_3_down"   )
wjets.AddNormPlusShapeHistoSys("w_plus_jets_scale_var", histoname_up = "4j1b_wjets_scale_var_up",   histoname_down = "4j1b_wjets_scale_var_down"    )
channel.AddSample(wjets)

single_top_s_chan = AGC_Sample("single_top_s", "4j1b_single_top_s_chan", input_file)
single_top_s_chan.SetSystematicsInputFile(input_file)
single_top_s_chan.ActivateStatError()
single_top_s_chan.AddOverallSys(lumi_systematics)
single_top_s_chan.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j1b_single_top_s_chan_pt_scale_up"                                                                 )
single_top_s_chan.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j1b_single_top_s_chan_pt_res_up"                                                                   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j1b_single_top_s_chan_btag_var_0_up",  histoname_down = "4j1b_single_top_s_chan_btag_var_0_down"   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j1b_single_top_s_chan_btag_var_1_up",  histoname_down = "4j1b_single_top_s_chan_btag_var_1_down"   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j1b_single_top_s_chan_btag_var_2_up",  histoname_down = "4j1b_single_top_s_chan_btag_var_2_down"   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j1b_single_top_s_chan_btag_var_3_up",  histoname_down = "4j1b_single_top_s_chan_btag_var_3_down"   )

channel.AddSample(single_top_s_chan)

single_top_t_chan = AGC_Sample("single_top_t", "4j1b_single_top_t_chan", input_file)
single_top_t_chan.SetSystematicsInputFile(input_file)
single_top_t_chan.ActivateStatError()
single_top_t_chan.AddOverallSys(lumi_systematics)
single_top_t_chan.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j1b_single_top_t_chan_pt_scale_up"                                                              )
single_top_t_chan.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j1b_single_top_t_chan_pt_res_up"                                                                )
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j1b_single_top_t_chan_btag_var_0_up",  histoname_down = "4j1b_single_top_t_chan_btag_var_0_down")
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j1b_single_top_t_chan_btag_var_1_up",  histoname_down = "4j1b_single_top_t_chan_btag_var_1_down")
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j1b_single_top_t_chan_btag_var_2_up",  histoname_down = "4j1b_single_top_t_chan_btag_var_2_down")
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j1b_single_top_t_chan_btag_var_3_up",  histoname_down = "4j1b_single_top_t_chan_btag_var_3_down")

channel.AddSample(single_top_t_chan)

single_top_tW = AGC_Sample("single_top_tW", "4j1b_single_top_tW", input_file)
single_top_tW.SetSystematicsInputFile(input_file)
single_top_tW.ActivateStatError()
single_top_tW.AddOverallSys(lumi_systematics)
single_top_tW.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j1b_single_top_tW_pt_scale_up"                                                                 )
single_top_tW.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up =  "4j1b_single_top_tW_pt_res_up"                                                                  )               
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j1b_single_top_tW_btag_var_0_up",      histoname_down = "4j1b_single_top_tW_btag_var_0_down"   )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j1b_single_top_tW_btag_var_1_up",      histoname_down = "4j1b_single_top_tW_btag_var_1_down"   )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j1b_single_top_tW_btag_var_2_up",      histoname_down = "4j1b_single_top_tW_btag_var_2_down"   )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j1b_single_top_tW_btag_var_3_up",      histoname_down = "4j1b_single_top_tW_btag_var_3_down"   )

channel.AddSample(single_top_tW)

meas.AddChannel(channel)

channel_2b = ROOT.RooStats.HistFactory.Channel("channel_4j2b_SR")
channel_2b.SetData("4j2b_pseudodata", input_file)
channel_2b.SetStatErrorConfig(0.001, "Gaussian")

ttbar = AGC_Sample("ttbar", "4j2b_ttbar", input_file)
ttbar.AddOverallSys(lumi_systematics)
ttbar.SetSystematicsInputFile(input_file)
ttbar.ActivateStatError()
ttbar.AddNormPlusShapeHistoSys("ME_variation",      histoname_up = "4j2b_ttbar_ME_var"                                                          )
ttbar.AddNormPlusShapeHistoSys("PS_variation",      histoname_up = "4j2b_ttbar_PS_var"                                                          )
ttbar.AddNormPlusShapeHistoSys("tt_scale_var",      histoname_up = "4j2b_ttbar_scaleup",        histoname_down = "4j2b_ttbar_scaledown"         )
ttbar.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j2b_ttbar_pt_scale_up"                                                     )
ttbar.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j2b_ttbar_pt_res_up"                                                       )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j2b_ttbar_btag_var_0_up",  histoname_down = "4j2b_ttbar_btag_var_0_down"   )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j2b_ttbar_btag_var_1_up",  histoname_down = "4j2b_ttbar_btag_var_1_down"   )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j2b_ttbar_btag_var_2_up",  histoname_down = "4j2b_ttbar_btag_var_2_down"   )
ttbar.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j2b_ttbar_btag_var_3_up",  histoname_down = "4j2b_ttbar_btag_var_3_down"   )
ttbar.AddNormFactor("ttbar_norm", 1, 0, 10)
channel_2b.AddSample(ttbar)

wjets = AGC_Sample("wjets", "4j2b_wjets", input_file)
wjets.SetSystematicsInputFile(input_file)
wjets.ActivateStatError()
wjets.AddOverallSys(lumi_systematics)
wjets.AddNormPlusShapeHistoSys("jet_energy_scale",      histoname_up = "4j2b_wjets_pt_scale_up"                                                     )
wjets.AddNormPlusShapeHistoSys("jet_energy_res",        histoname_up = "4j2b_wjets_pt_res_up"                                                       )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_1",            histoname_up = "4j2b_wjets_btag_var_0_up",  histoname_down = "4j2b_wjets_btag_var_0_down"   )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_2",            histoname_up = "4j2b_wjets_btag_var_1_up",  histoname_down = "4j2b_wjets_btag_var_1_down"   )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_3",            histoname_up = "4j2b_wjets_btag_var_2_up",  histoname_down = "4j2b_wjets_btag_var_2_down"   )
wjets.AddNormPlusShapeHistoSys("b_tag_NP_4",            histoname_up = "4j2b_wjets_btag_var_3_up",  histoname_down = "4j2b_wjets_btag_var_3_down"   )
wjets.AddNormPlusShapeHistoSys("w_plus_jets_scale_var", histoname_up = "4j2b_wjets_scale_var_up",   histoname_down = "4j2b_wjets_scale_var_down"    )
channel_2b.AddSample(wjets)

single_top_s_chan = AGC_Sample("single_top_s", "4j2b_single_top_s_chan", input_file)
single_top_s_chan.SetSystematicsInputFile(input_file)
single_top_s_chan.ActivateStatError()
single_top_s_chan.AddOverallSys(lumi_systematics)
single_top_s_chan.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j2b_single_top_s_chan_pt_scale_up"                                                                 )
single_top_s_chan.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j2b_single_top_s_chan_pt_res_up"                                                                   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j2b_single_top_s_chan_btag_var_0_up",  histoname_down = "4j2b_single_top_s_chan_btag_var_0_down"   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j2b_single_top_s_chan_btag_var_1_up",  histoname_down = "4j2b_single_top_s_chan_btag_var_1_down"   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j2b_single_top_s_chan_btag_var_2_up",  histoname_down = "4j2b_single_top_s_chan_btag_var_2_down"   )
single_top_s_chan.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j2b_single_top_s_chan_btag_var_3_up",  histoname_down = "4j2b_single_top_s_chan_btag_var_3_down"   )
channel_2b.AddSample(single_top_s_chan)

single_top_t_chan = AGC_Sample("single_top_t", "4j2b_single_top_t_chan", input_file)
single_top_t_chan.SetSystematicsInputFile(input_file)
single_top_t_chan.ActivateStatError()
single_top_t_chan.AddOverallSys(lumi_systematics)
single_top_t_chan.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j2b_single_top_t_chan_pt_scale_up"                                                                 )
single_top_t_chan.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j2b_single_top_t_chan_pt_res_up"                                                                   )
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j2b_single_top_t_chan_btag_var_0_up",  histoname_down = "4j2b_single_top_t_chan_btag_var_0_down"   )
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j2b_single_top_t_chan_btag_var_1_up",  histoname_down = "4j2b_single_top_t_chan_btag_var_1_down"   )
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j2b_single_top_t_chan_btag_var_2_up",  histoname_down = "4j2b_single_top_t_chan_btag_var_2_down"   )
single_top_t_chan.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j2b_single_top_t_chan_btag_var_3_up",  histoname_down = "4j2b_single_top_t_chan_btag_var_3_down"   )

channel_2b.AddSample(single_top_t_chan)

single_top_tW = AGC_Sample("single_top_tW", "4j2b_single_top_tW", input_file)
single_top_tW.ActivateStatError()
single_top_tW.SetSystematicsInputFile(input_file)
single_top_tW.AddOverallSys(lumi_systematics)
single_top_tW.AddNormPlusShapeHistoSys("jet_energy_scale",  histoname_up = "4j2b_single_top_tW_pt_scale_up"                                                             )
single_top_tW.AddNormPlusShapeHistoSys("jet_energy_res",    histoname_up = "4j2b_single_top_tW_pt_res_up"                                                               )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_1",        histoname_up = "4j2b_single_top_tW_btag_var_0_up",  histoname_down = "4j2b_single_top_tW_btag_var_0_down"   )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_2",        histoname_up = "4j2b_single_top_tW_btag_var_1_up",  histoname_down = "4j2b_single_top_tW_btag_var_1_down"   )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_3",        histoname_up = "4j2b_single_top_tW_btag_var_2_up",  histoname_down = "4j2b_single_top_tW_btag_var_2_down"   )
single_top_tW.AddNormPlusShapeHistoSys("b_tag_NP_4",        histoname_up = "4j2b_single_top_tW_btag_var_3_up",  histoname_down = "4j2b_single_top_tW_btag_var_3_down"   )

channel_2b.AddSample(single_top_tW)
meas.AddChannel(channel_2b)

# %%
meas.SetPOI("ttbar_norm")
meas.CollectHistograms()
meas.SetExportOnly(True)
# Out:
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j1b_pseudodata
# [#2] INFO:HistFactory -- Opened input file: data/temp_histos.root:
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j1b_ttbar
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_ME_variation_norm_plus_shape_down
# [#2] INFO:HistFactory -- Opened input file: data/HistFactoryExtra.root:
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_ME_variation_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_PS_variation_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_PS_variation_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_tt_scale_var_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_tt_scale_var_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_ttbar_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j1b_wjets
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_w_plus_jets_scale_var_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_wjets_w_plus_jets_scale_var_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j1b_single_top_s_chan
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_s_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j1b_single_top_t_chan
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_t_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j1b_single_top_tW
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j1b_single_top_tW_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j2b_pseudodata
# [#2] INFO:HistFactory -- Opened input file: data/temp_histos.root:
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j2b_ttbar
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_ME_variation_norm_plus_shape_down
# [#2] INFO:HistFactory -- Opened input file: data/HistFactoryExtra.root:
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_ME_variation_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_PS_variation_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_PS_variation_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_tt_scale_var_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_tt_scale_var_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_ttbar_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j2b_wjets
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_w_plus_jets_scale_var_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_wjets_w_plus_jets_scale_var_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j2b_single_top_s_chan
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_s_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j2b_single_top_t_chan
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_t_b_tag_NP_4_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/temp_histos.root:/4j2b_single_top_tW
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_jet_energy_scale_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_jet_energy_scale_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_jet_energy_res_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_jet_energy_res_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_1_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_1_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_2_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_2_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_3_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_3_norm_plus_shape_up
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_4_norm_plus_shape_down
# [#2] PROGRESS:HistFactory -- Getting histogram data/HistFactoryExtra.root:/4j2b_single_top_tW_b_tag_NP_4_norm_plus_shape_up

# %%
ws = ROOT.RooStats.HistFactory.MakeModelAndMeasurementFast(meas)

# Retrieve the ModelConfig
modelConfig = ws.obj("ModelConfig")

# Extract the PDF and global observables
pdf = modelConfig.GetPdf()
globalObservables = ROOT.RooArgSet(modelConfig.GetGlobalObservables())

# Perform the fit
result = pdf.fitTo(ws.data("obsData"), ROOT.RooFit.Save(), ROOT.RooFit.PrintLevel(-1), ROOT.RooFit.GlobalObservables(globalObservables))
# Out:
# [#2] INFO:HistFactory -- Making Model and Measurements (Fast) for measurement: meas
# [#2] INFO:HistFactory -- using lumi = 1 and lumiError = 0 including bins between 0 and 1
# [#2] INFO:HistFactory -- fixing the following parameters:
# [#2] INFO:HistFactory -- Creating the output file: _meas.root
# [#2] INFO:HistFactory -- Creating the HistoToWorkspaceFactoryFast factory
# [#2] INFO:HistFactory -- Setting preprocess functions
# [#2] PROGRESS:HistFactory -- Starting to process channel: channel_4j1b_CR
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	Starting to process 'channel_4j1b_CR' channel with 1 observables
# -----------------------------------------
#
# [#2] INFO:HistFactory -- making normFactor: ttbar_norm
# [#2] INFO:HistFactory -- processing hist 4j1b_ttbartemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: ttbar to be included in Stat Error for channel channel_4j1b_CR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j1b_CR Sample: ttbar
# [#2] INFO:HistFactory -- processing hist 4j1b_wjetstemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: wjets to be included in Stat Error for channel channel_4j1b_CR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j1b_CR Sample: wjets
# [#2] INFO:HistFactory -- processing hist 4j1b_single_top_s_chantemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: single_top_s to be included in Stat Error for channel channel_4j1b_CR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j1b_CR Sample: single_top_s
# [#2] INFO:HistFactory -- processing hist 4j1b_single_top_t_chantemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: single_top_t to be included in Stat Error for channel channel_4j1b_CR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j1b_CR Sample: single_top_t
# [#2] INFO:HistFactory -- processing hist 4j1b_single_top_tWtemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: single_top_tW to be included in Stat Error for channel channel_4j1b_CR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j1b_CR Sample: single_top_tW
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 1 Error = 18.3904 CentralVal = 109.415 RelativeError = 0.168079
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 2 Error = 70.286 CentralVal = 1856.85 RelativeError = 0.0378523
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 3 Error = 85.0272 CentralVal = 4224.22 RelativeError = 0.0201285
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 4 Error = 94.2739 CentralVal = 5036.66 RelativeError = 0.0187176
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 5 Error = 87.828 CentralVal = 4482.4 RelativeError = 0.0195939
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 6 Error = 78.2041 CentralVal = 3597.33 RelativeError = 0.0217395
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 7 Error = 67.9509 CentralVal = 2786 RelativeError = 0.0243901
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 8 Error = 72.5251 CentralVal = 2286.17 RelativeError = 0.0317235
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 9 Error = 61.3768 CentralVal = 1692.97 RelativeError = 0.0362539
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 10 Error = 48.0562 CentralVal = 1189.39 RelativeError = 0.0404042
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 11 Error = 48.8669 CentralVal = 996.554 RelativeError = 0.0490359
# [#2] INFO:HistFactory -- About to create Constraint Terms from: mc_stat_channel_4j1b_CR params: (gamma_stat_channel_4j1b_CR_bin_0,gamma_stat_channel_4j1b_CR_bin_1,gamma_stat_channel_4j1b_CR_bin_2,gamma_stat_channel_4j1b_CR_bin_3,gamma_stat_channel_4j1b_CR_bin_4,gamma_stat_channel_4j1b_CR_bin_5,gamma_stat_channel_4j1b_CR_bin_6,gamma_stat_channel_4j1b_CR_bin_7,gamma_stat_channel_4j1b_CR_bin_8,gamma_stat_channel_4j1b_CR_bin_9,gamma_stat_channel_4j1b_CR_bin_10)
# [#2] INFO:HistFactory -- Using Gaussian StatErrors in channel: channel_4j1b_CR
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_0. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_1. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_2. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_3. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_4. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_5. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_6. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_7. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_8. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_9. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j1b_CR_bin_10. Type of constraint: 0
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	import model into workspace
# -----------------------------------------
#
# RooDataSet::AsimovData[obs_x_channel_4j1b_CR,weight:binWeightAsimov] = 11 entries (28257.9 weighted)
#
# RooWorkspace(channel_4j1b_CR) channel_4j1b_CR workspace contents
#
# variables
# ---------
# (Lumi,alpha_Lumi,alpha_ME_variation,alpha_PS_variation,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4,alpha_jet_energy_res,alpha_jet_energy_scale,alpha_tt_scale_var,alpha_w_plus_jets_scale_var,gamma_stat_channel_4j1b_CR_bin_0,gamma_stat_channel_4j1b_CR_bin_1,gamma_stat_channel_4j1b_CR_bin_10,gamma_stat_channel_4j1b_CR_bin_2,gamma_stat_channel_4j1b_CR_bin_3,gamma_stat_channel_4j1b_CR_bin_4,gamma_stat_channel_4j1b_CR_bin_5,gamma_stat_channel_4j1b_CR_bin_6,gamma_stat_channel_4j1b_CR_bin_7,gamma_stat_channel_4j1b_CR_bin_8,gamma_stat_channel_4j1b_CR_bin_9,nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_jet_energy_res,nom_alpha_jet_energy_scale,nom_alpha_tt_scale_var,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_10,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,obs_x_channel_4j1b_CR,ttbar_norm)
#
# p.d.f.s
# -------
# RooGaussian::alpha_LumiConstraint[ x=alpha_Lumi mean=nom_alpha_Lumi sigma=1 ] = 1
# RooGaussian::alpha_ME_variationConstraint[ x=alpha_ME_variation mean=nom_alpha_ME_variation sigma=1 ] = 1
# RooGaussian::alpha_PS_variationConstraint[ x=alpha_PS_variation mean=nom_alpha_PS_variation sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_1Constraint[ x=alpha_b_tag_NP_1 mean=nom_alpha_b_tag_NP_1 sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_2Constraint[ x=alpha_b_tag_NP_2 mean=nom_alpha_b_tag_NP_2 sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_3Constraint[ x=alpha_b_tag_NP_3 mean=nom_alpha_b_tag_NP_3 sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_4Constraint[ x=alpha_b_tag_NP_4 mean=nom_alpha_b_tag_NP_4 sigma=1 ] = 1
# RooGaussian::alpha_jet_energy_resConstraint[ x=alpha_jet_energy_res mean=nom_alpha_jet_energy_res sigma=1 ] = 1
# RooGaussian::alpha_jet_energy_scaleConstraint[ x=alpha_jet_energy_scale mean=nom_alpha_jet_energy_scale sigma=1 ] = 1
# RooGaussian::alpha_tt_scale_varConstraint[ x=alpha_tt_scale_var mean=nom_alpha_tt_scale_var sigma=1 ] = 1
# RooGaussian::alpha_w_plus_jets_scale_varConstraint[ x=alpha_w_plus_jets_scale_var mean=nom_alpha_w_plus_jets_scale_var sigma=1 ] = 1
# RooRealSumPdf::channel_4j1b_CR_model[ ttbar_channel_4j1b_CR_scaleFactors * ttbar_channel_4j1b_CR_shapes + wjets_channel_4j1b_CR_scaleFactors * wjets_channel_4j1b_CR_shapes + single_top_s_channel_4j1b_CR_scaleFactors * single_top_s_channel_4j1b_CR_shapes + single_top_t_channel_4j1b_CR_scaleFactors * single_top_t_channel_4j1b_CR_shapes + single_top_tW_channel_4j1b_CR_scaleFactors * single_top_tW_channel_4j1b_CR_shapes ] = 24.9139/28257.9
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_0_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_0 mean=gamma_stat_channel_4j1b_CR_bin_0 sigma=gamma_stat_channel_4j1b_CR_bin_0_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_10_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_10 mean=gamma_stat_channel_4j1b_CR_bin_10 sigma=gamma_stat_channel_4j1b_CR_bin_10_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_1_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_1 mean=gamma_stat_channel_4j1b_CR_bin_1 sigma=gamma_stat_channel_4j1b_CR_bin_1_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_2_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_2 mean=gamma_stat_channel_4j1b_CR_bin_2 sigma=gamma_stat_channel_4j1b_CR_bin_2_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_3_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_3 mean=gamma_stat_channel_4j1b_CR_bin_3 sigma=gamma_stat_channel_4j1b_CR_bin_3_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_4_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_4 mean=gamma_stat_channel_4j1b_CR_bin_4 sigma=gamma_stat_channel_4j1b_CR_bin_4_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_5_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_5 mean=gamma_stat_channel_4j1b_CR_bin_5 sigma=gamma_stat_channel_4j1b_CR_bin_5_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_6_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_6 mean=gamma_stat_channel_4j1b_CR_bin_6 sigma=gamma_stat_channel_4j1b_CR_bin_6_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_7_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_7 mean=gamma_stat_channel_4j1b_CR_bin_7 sigma=gamma_stat_channel_4j1b_CR_bin_7_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_8_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_8 mean=gamma_stat_channel_4j1b_CR_bin_8 sigma=gamma_stat_channel_4j1b_CR_bin_8_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j1b_CR_bin_9_constraint[ x=nom_gamma_stat_channel_4j1b_CR_bin_9 mean=gamma_stat_channel_4j1b_CR_bin_9 sigma=gamma_stat_channel_4j1b_CR_bin_9_sigma ] = 1
# RooProdPdf::model_channel_4j1b_CR[ alpha_LumiConstraint * alpha_ME_variationConstraint * alpha_PS_variationConstraint * alpha_tt_scale_varConstraint * alpha_jet_energy_scaleConstraint * alpha_jet_energy_resConstraint * alpha_b_tag_NP_1Constraint * alpha_b_tag_NP_2Constraint * alpha_b_tag_NP_3Constraint * alpha_b_tag_NP_4Constraint * alpha_w_plus_jets_scale_varConstraint * gamma_stat_channel_4j1b_CR_bin_0_constraint * gamma_stat_channel_4j1b_CR_bin_1_constraint * gamma_stat_channel_4j1b_CR_bin_2_constraint * gamma_stat_channel_4j1b_CR_bin_3_constraint * gamma_stat_channel_4j1b_CR_bin_4_constraint * gamma_stat_channel_4j1b_CR_bin_5_constraint * gamma_stat_channel_4j1b_CR_bin_6_constraint * gamma_stat_channel_4j1b_CR_bin_7_constraint * gamma_stat_channel_4j1b_CR_bin_8_constraint * gamma_stat_channel_4j1b_CR_bin_9_constraint * gamma_stat_channel_4j1b_CR_bin_10_constraint * channel_4j1b_CR_model(obs_x_channel_4j1b_CR) ] = 24.9139
#
# functions
# --------
# RooBinWidthFunction::channel_4j1b_CR_model_binWidth[ HistFuncForBinWidth=ttbar_channel_4j1b_CR_Hist_alphanominal ] = 0.025
# ParamHistFunc::mc_stat_channel_4j1b_CR[ ] = 1
# PiecewiseInterpolation::single_top_s_channel_4j1b_CR_Hist_alpha[ ] = 0.323503
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_0high[ depList=(obs_x_channel_4j1b_CR) ] = 0.30076
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_0low[ depList=(obs_x_channel_4j1b_CR) ] = 0.346245
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_1high[ depList=(obs_x_channel_4j1b_CR) ] = 0.333288
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_1low[ depList=(obs_x_channel_4j1b_CR) ] = 0.313717
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_2high[ depList=(obs_x_channel_4j1b_CR) ] = 0.365285
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_2low[ depList=(obs_x_channel_4j1b_CR) ] = 0.262182
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_3high[ depList=(obs_x_channel_4j1b_CR) ] = 0.347222
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_3low[ depList=(obs_x_channel_4j1b_CR) ] = 0.293229
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_4high[ depList=(obs_x_channel_4j1b_CR) ] = 0.336799
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_4low[ depList=(obs_x_channel_4j1b_CR) ] = 0.307765
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_5high[ depList=(obs_x_channel_4j1b_CR) ] = 0.330526
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alpha_5low[ depList=(obs_x_channel_4j1b_CR) ] = 0.315541
# RooHistFunc::single_top_s_channel_4j1b_CR_Hist_alphanominal[ depList=(obs_x_channel_4j1b_CR) ] = 0.323503
# RooStats::HistFactory::FlexibleInterpVar::single_top_s_channel_4j1b_CR_epsilon[ paramList=(alpha_Lumi,alpha_jet_energy_scale,alpha_jet_energy_res,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4) ] = 1
# RooProduct::single_top_s_channel_4j1b_CR_scaleFactors[ single_top_s_channel_4j1b_CR_epsilon * Lumi ] = 1
# RooProduct::single_top_s_channel_4j1b_CR_shapes[ single_top_s_channel_4j1b_CR_Hist_alpha * mc_stat_channel_4j1b_CR * channel_4j1b_CR_model_binWidth ] = 0.00808756
# PiecewiseInterpolation::single_top_tW_channel_4j1b_CR_Hist_alpha[ ] = 49.9729
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_0high[ depList=(obs_x_channel_4j1b_CR) ] = 52.5561
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_0low[ depList=(obs_x_channel_4j1b_CR) ] = 47.3897
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_1high[ depList=(obs_x_channel_4j1b_CR) ] = 53.1092
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_1low[ depList=(obs_x_channel_4j1b_CR) ] = 46.8366
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_2high[ depList=(obs_x_channel_4j1b_CR) ] = 56.6907
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_2low[ depList=(obs_x_channel_4j1b_CR) ] = 40.3769
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_3high[ depList=(obs_x_channel_4j1b_CR) ] = 53.6774
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_3low[ depList=(obs_x_channel_4j1b_CR) ] = 45.3035
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_4high[ depList=(obs_x_channel_4j1b_CR) ] = 51.9297
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_4low[ depList=(obs_x_channel_4j1b_CR) ] = 47.6616
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_5high[ depList=(obs_x_channel_4j1b_CR) ] = 50.9723
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alpha_5low[ depList=(obs_x_channel_4j1b_CR) ] = 48.8403
# RooHistFunc::single_top_tW_channel_4j1b_CR_Hist_alphanominal[ depList=(obs_x_channel_4j1b_CR) ] = 49.9729
# RooStats::HistFactory::FlexibleInterpVar::single_top_tW_channel_4j1b_CR_epsilon[ paramList=(alpha_Lumi,alpha_jet_energy_scale,alpha_jet_energy_res,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4) ] = 1
# RooProduct::single_top_tW_channel_4j1b_CR_scaleFactors[ single_top_tW_channel_4j1b_CR_epsilon * Lumi ] = 1
# RooProduct::single_top_tW_channel_4j1b_CR_shapes[ single_top_tW_channel_4j1b_CR_Hist_alpha * mc_stat_channel_4j1b_CR * channel_4j1b_CR_model_binWidth ] = 1.24932
# PiecewiseInterpolation::single_top_t_channel_4j1b_CR_Hist_alpha[ ] = 19.0479
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_0high[ depList=(obs_x_channel_4j1b_CR) ] = 18.8659
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_0low[ depList=(obs_x_channel_4j1b_CR) ] = 19.2299
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_1high[ depList=(obs_x_channel_4j1b_CR) ] = 16.9793
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_1low[ depList=(obs_x_channel_4j1b_CR) ] = 21.1166
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_2high[ depList=(obs_x_channel_4j1b_CR) ] = 21.5409
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_2low[ depList=(obs_x_channel_4j1b_CR) ] = 15.422
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_3high[ depList=(obs_x_channel_4j1b_CR) ] = 20.4007
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_3low[ depList=(obs_x_channel_4j1b_CR) ] = 17.3295
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_4high[ depList=(obs_x_channel_4j1b_CR) ] = 19.7298
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_4low[ depList=(obs_x_channel_4j1b_CR) ] = 18.2415
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_5high[ depList=(obs_x_channel_4j1b_CR) ] = 19.4159
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alpha_5low[ depList=(obs_x_channel_4j1b_CR) ] = 18.631
# RooHistFunc::single_top_t_channel_4j1b_CR_Hist_alphanominal[ depList=(obs_x_channel_4j1b_CR) ] = 19.0479
# RooStats::HistFactory::FlexibleInterpVar::single_top_t_channel_4j1b_CR_epsilon[ paramList=(alpha_Lumi,alpha_jet_energy_scale,alpha_jet_energy_res,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4) ] = 1
# RooProduct::single_top_t_channel_4j1b_CR_scaleFactors[ single_top_t_channel_4j1b_CR_epsilon * Lumi ] = 1
# RooProduct::single_top_t_channel_4j1b_CR_shapes[ single_top_t_channel_4j1b_CR_Hist_alpha * mc_stat_channel_4j1b_CR * channel_4j1b_CR_model_binWidth ] = 0.476198
# PiecewiseInterpolation::ttbar_channel_4j1b_CR_Hist_alpha[ ] = 688.327
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_0high[ depList=(obs_x_channel_4j1b_CR) ] = 879.491
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_0low[ depList=(obs_x_channel_4j1b_CR) ] = 497.163
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_1high[ depList=(obs_x_channel_4j1b_CR) ] = 591.48
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_1low[ depList=(obs_x_channel_4j1b_CR) ] = 785.174
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_2high[ depList=(obs_x_channel_4j1b_CR) ] = 671.909
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_2low[ depList=(obs_x_channel_4j1b_CR) ] = 680.576
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_3high[ depList=(obs_x_channel_4j1b_CR) ] = 699.187
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_3low[ depList=(obs_x_channel_4j1b_CR) ] = 677.467
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_4high[ depList=(obs_x_channel_4j1b_CR) ] = 688.533
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_4low[ depList=(obs_x_channel_4j1b_CR) ] = 688.121
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_5high[ depList=(obs_x_channel_4j1b_CR) ] = 767.181
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_5low[ depList=(obs_x_channel_4j1b_CR) ] = 576.143
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_6high[ depList=(obs_x_channel_4j1b_CR) ] = 735.885
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_6low[ depList=(obs_x_channel_4j1b_CR) ] = 628.059
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_7high[ depList=(obs_x_channel_4j1b_CR) ] = 716.197
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_7low[ depList=(obs_x_channel_4j1b_CR) ] = 655.229
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_8high[ depList=(obs_x_channel_4j1b_CR) ] = 705.116
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alpha_8low[ depList=(obs_x_channel_4j1b_CR) ] = 669.225
# RooHistFunc::ttbar_channel_4j1b_CR_Hist_alphanominal[ depList=(obs_x_channel_4j1b_CR) ] = 688.327
# RooStats::HistFactory::FlexibleInterpVar::ttbar_channel_4j1b_CR_epsilon[ paramList=(alpha_Lumi,alpha_ME_variation,alpha_PS_variation,alpha_tt_scale_var,alpha_jet_energy_scale,alpha_jet_energy_res,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4) ] = 1
# RooProduct::ttbar_channel_4j1b_CR_scaleFactors[ ttbar_channel_4j1b_CR_epsilon * ttbar_norm * Lumi ] = 1
# RooProduct::ttbar_channel_4j1b_CR_shapes[ ttbar_channel_4j1b_CR_Hist_alpha * mc_stat_channel_4j1b_CR * channel_4j1b_CR_model_binWidth ] = 17.2082
# PiecewiseInterpolation::wjets_channel_4j1b_CR_Hist_alpha[ ] = 238.883
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_0high[ depList=(obs_x_channel_4j1b_CR) ] = 204.528
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_0low[ depList=(obs_x_channel_4j1b_CR) ] = 273.238
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_1high[ depList=(obs_x_channel_4j1b_CR) ] = 249.025
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_1low[ depList=(obs_x_channel_4j1b_CR) ] = 228.741
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_2high[ depList=(obs_x_channel_4j1b_CR) ] = 267.477
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_2low[ depList=(obs_x_channel_4j1b_CR) ] = 196.394
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_3high[ depList=(obs_x_channel_4j1b_CR) ] = 258.396
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_3low[ depList=(obs_x_channel_4j1b_CR) ] = 213.883
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_4high[ depList=(obs_x_channel_4j1b_CR) ] = 249.409
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_4low[ depList=(obs_x_channel_4j1b_CR) ] = 226.527
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_5high[ depList=(obs_x_channel_4j1b_CR) ] = 243.112
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_5low[ depList=(obs_x_channel_4j1b_CR) ] = 234.116
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_6high[ depList=(obs_x_channel_4j1b_CR) ] = 238.883
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alpha_6low[ depList=(obs_x_channel_4j1b_CR) ] = 238.883
# RooHistFunc::wjets_channel_4j1b_CR_Hist_alphanominal[ depList=(obs_x_channel_4j1b_CR) ] = 238.883
# RooStats::HistFactory::FlexibleInterpVar::wjets_channel_4j1b_CR_epsilon[ paramList=(alpha_Lumi,alpha_jet_energy_scale,alpha_jet_energy_res,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4,alpha_w_plus_jets_scale_var) ] = 1
# RooProduct::wjets_channel_4j1b_CR_scaleFactors[ wjets_channel_4j1b_CR_epsilon * Lumi ] = 1
# RooProduct::wjets_channel_4j1b_CR_shapes[ wjets_channel_4j1b_CR_Hist_alpha * mc_stat_channel_4j1b_CR * channel_4j1b_CR_model_binWidth ] = 5.97207
#
# datasets
# --------
# RooDataSet::asimovData(obs_x_channel_4j1b_CR)
# RooDataSet::obsData(obs_x_channel_4j1b_CR)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alphanominalDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_0lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_1lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_2lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_3lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_4lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_5lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_6lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_7lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_8lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_0highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_1highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_2highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_3highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_4highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_5highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_6highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_7highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::ttbar_channel_4j1b_CR_Hist_alpha_8highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alphanominalDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_0lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_1lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_2lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_3lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_4lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_5lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_6lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_0highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_1highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_2highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_3highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_4highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_5highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::wjets_channel_4j1b_CR_Hist_alpha_6highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alphanominalDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_0lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_1lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_2lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_3lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_4lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_5lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_0highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_1highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_2highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_3highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_4highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_s_channel_4j1b_CR_Hist_alpha_5highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alphanominalDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_0lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_1lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_2lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_3lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_4lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_5lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_0highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_1highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_2highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_3highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_4highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_t_channel_4j1b_CR_Hist_alpha_5highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alphanominalDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_0lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_1lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_2lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_3lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_4lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_5lowDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_0highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_1highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_2highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_3highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_4highDHist(obs_x_channel_4j1b_CR)
# RooDataHist::single_top_tW_channel_4j1b_CR_Hist_alpha_5highDHist(obs_x_channel_4j1b_CR)
#
# named sets
# ----------
# ModelConfig_GlobalObservables:(nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j1b_CR_bin_10)
# ModelConfig_Observables:(obs_x_channel_4j1b_CR)
# constraintTerms:(alpha_LumiConstraint,alpha_ME_variationConstraint,alpha_PS_variationConstraint,alpha_tt_scale_varConstraint,alpha_jet_energy_scaleConstraint,alpha_jet_energy_resConstraint,alpha_b_tag_NP_1Constraint,alpha_b_tag_NP_2Constraint,alpha_b_tag_NP_3Constraint,alpha_b_tag_NP_4Constraint,alpha_w_plus_jets_scale_varConstraint,gamma_stat_channel_4j1b_CR_bin_0_constraint,gamma_stat_channel_4j1b_CR_bin_1_constraint,gamma_stat_channel_4j1b_CR_bin_2_constraint,gamma_stat_channel_4j1b_CR_bin_3_constraint,gamma_stat_channel_4j1b_CR_bin_4_constraint,gamma_stat_channel_4j1b_CR_bin_5_constraint,gamma_stat_channel_4j1b_CR_bin_6_constraint,gamma_stat_channel_4j1b_CR_bin_7_constraint,gamma_stat_channel_4j1b_CR_bin_8_constraint,gamma_stat_channel_4j1b_CR_bin_9_constraint,gamma_stat_channel_4j1b_CR_bin_10_constraint)
# globalObservables:(nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j1b_CR_bin_10)
# likelihoodTerms:(channel_4j1b_CR_model)
# observables:(obs_x_channel_4j1b_CR)
# observablesSet:(obs_x_channel_4j1b_CR)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
#
# [#2] INFO:HistFactory -- Setting Parameter(s) of Interest as: ttbar_norm
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (obs_x_channel_4j1b_CR)
# Parameters of Interest:  RooArgSet:: = (ttbar_norm)
# Nuisance Parameters:     RooArgSet:: = (alpha_Lumi,alpha_ME_variation,alpha_PS_variation,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4,alpha_jet_energy_res,alpha_jet_energy_scale,alpha_tt_scale_var,alpha_w_plus_jets_scale_var,gamma_stat_channel_4j1b_CR_bin_0,gamma_stat_channel_4j1b_CR_bin_1,gamma_stat_channel_4j1b_CR_bin_10,gamma_stat_channel_4j1b_CR_bin_2,gamma_stat_channel_4j1b_CR_bin_3,gamma_stat_channel_4j1b_CR_bin_4,gamma_stat_channel_4j1b_CR_bin_5,gamma_stat_channel_4j1b_CR_bin_6,gamma_stat_channel_4j1b_CR_bin_7,gamma_stat_channel_4j1b_CR_bin_8,gamma_stat_channel_4j1b_CR_bin_9)
# Global Observables:      RooArgSet:: = (nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j1b_CR_bin_10)
# PDF:                     RooProdPdf::model_channel_4j1b_CR[ alpha_LumiConstraint * alpha_ME_variationConstraint * alpha_PS_variationConstraint * alpha_tt_scale_varConstraint * alpha_jet_energy_scaleConstraint * alpha_jet_energy_resConstraint * alpha_b_tag_NP_1Constraint * alpha_b_tag_NP_2Constraint * alpha_b_tag_NP_3Constraint * alpha_b_tag_NP_4Constraint * alpha_w_plus_jets_scale_varConstraint * gamma_stat_channel_4j1b_CR_bin_0_constraint * gamma_stat_channel_4j1b_CR_bin_1_constraint * gamma_stat_channel_4j1b_CR_bin_2_constraint * gamma_stat_channel_4j1b_CR_bin_3_constraint * gamma_stat_channel_4j1b_CR_bin_4_constraint * gamma_stat_channel_4j1b_CR_bin_5_constraint * gamma_stat_channel_4j1b_CR_bin_6_constraint * gamma_stat_channel_4j1b_CR_bin_7_constraint * gamma_stat_channel_4j1b_CR_bin_8_constraint * gamma_stat_channel_4j1b_CR_bin_9_constraint * gamma_stat_channel_4j1b_CR_bin_10_constraint * channel_4j1b_CR_model(obs_x_channel_4j1b_CR) ] = 24.9139
#
# [#2] INFO:HistFactory -- Opening File to hold channel: _channel_4j1b_CR_meas_model.root
# [#2] INFO:HistFactory -- About to write channel measurement to file
# [#2] PROGRESS:HistFactory -- Writing sample: ttbar
# [#2] PROGRESS:HistFactory -- Writing sample: wjets
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_s
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_t
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_tW
# [#2] PROGRESS:HistFactory -- Saved all histograms
# [#2] PROGRESS:HistFactory -- Saved Measurement
# [#2] PROGRESS:HistFactory -- Successfully wrote channel to file
# [#2] PROGRESS:HistFactory -- Starting to process channel: channel_4j2b_SR
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	Starting to process 'channel_4j2b_SR' channel with 1 observables
# -----------------------------------------
#
# [#2] INFO:HistFactory -- making normFactor: ttbar_norm
# [#2] INFO:HistFactory -- processing hist 4j2b_ttbartemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: ttbar to be included in Stat Error for channel channel_4j2b_SR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j2b_SR Sample: ttbar
# [#2] INFO:HistFactory -- processing hist 4j2b_wjetstemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: wjets to be included in Stat Error for channel channel_4j2b_SR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j2b_SR Sample: wjets
# [#2] INFO:HistFactory -- processing hist 4j2b_single_top_s_chantemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: single_top_s to be included in Stat Error for channel channel_4j2b_SR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j2b_SR Sample: single_top_s
# [#2] INFO:HistFactory -- processing hist 4j2b_single_top_t_chantemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: single_top_t to be included in Stat Error for channel channel_4j2b_SR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j2b_SR Sample: single_top_t
# [#2] INFO:HistFactory -- processing hist 4j2b_single_top_tWtemp_rebin_clone
# [#2] INFO:HistFactory -- Sample: single_top_tW to be included in Stat Error for channel channel_4j2b_SR
# [#2] INFO:HistFactory -- Making Statistical Uncertainty Hist for  Channel: channel_4j2b_SR Sample: single_top_tW
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 1 Error = 70.9512 CentralVal = 8460.81 RelativeError = 0.00838587
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 2 Error = 87.0942 CentralVal = 15394.1 RelativeError = 0.00565765
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 3 Error = 73.3895 CentralVal = 8435.19 RelativeError = 0.00870039
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 4 Error = 64.2669 CentralVal = 5508.6 RelativeError = 0.0116667
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 5 Error = 55.8668 CentralVal = 3998.47 RelativeError = 0.013972
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 6 Error = 46.6663 CentralVal = 2876.54 RelativeError = 0.0162231
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 7 Error = 39.0847 CentralVal = 2137.43 RelativeError = 0.0182858
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 8 Error = 35.4332 CentralVal = 1593.49 RelativeError = 0.0222362
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 9 Error = 34.7391 CentralVal = 1258.46 RelativeError = 0.0276043
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 10 Error = 33.3584 CentralVal = 1004.94 RelativeError = 0.0331944
# [#2] INFO:HistFactory -- Making Total Uncertainty for bin 11 Error = 22.2529 CentralVal = 752.42 RelativeError = 0.0295751
# [#2] INFO:HistFactory -- About to create Constraint Terms from: mc_stat_channel_4j2b_SR params: (gamma_stat_channel_4j2b_SR_bin_0,gamma_stat_channel_4j2b_SR_bin_1,gamma_stat_channel_4j2b_SR_bin_2,gamma_stat_channel_4j2b_SR_bin_3,gamma_stat_channel_4j2b_SR_bin_4,gamma_stat_channel_4j2b_SR_bin_5,gamma_stat_channel_4j2b_SR_bin_6,gamma_stat_channel_4j2b_SR_bin_7,gamma_stat_channel_4j2b_SR_bin_8,gamma_stat_channel_4j2b_SR_bin_9,gamma_stat_channel_4j2b_SR_bin_10)
# [#2] INFO:HistFactory -- Using Gaussian StatErrors in channel: channel_4j2b_SR
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_0. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_1. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_2. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_3. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_4. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_5. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_6. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_7. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_8. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_9. Type of constraint: 0
# [#2] INFO:HistFactory -- Creating constraint for: gamma_stat_channel_4j2b_SR_bin_10. Type of constraint: 0
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	import model into workspace
# -----------------------------------------
#
# RooDataSet::AsimovData[obs_x_channel_4j2b_SR,weight:binWeightAsimov] = 11 entries (51420.4 weighted)
#
# RooWorkspace(channel_4j2b_SR) channel_4j2b_SR workspace contents
#
# variables
# ---------
# (Lumi,alpha_Lumi,alpha_ME_variation,alpha_PS_variation,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4,alpha_jet_energy_res,alpha_jet_energy_scale,alpha_tt_scale_var,alpha_w_plus_jets_scale_var,gamma_stat_channel_4j2b_SR_bin_0,gamma_stat_channel_4j2b_SR_bin_1,gamma_stat_channel_4j2b_SR_bin_10,gamma_stat_channel_4j2b_SR_bin_2,gamma_stat_channel_4j2b_SR_bin_3,gamma_stat_channel_4j2b_SR_bin_4,gamma_stat_channel_4j2b_SR_bin_5,gamma_stat_channel_4j2b_SR_bin_6,gamma_stat_channel_4j2b_SR_bin_7,gamma_stat_channel_4j2b_SR_bin_8,gamma_stat_channel_4j2b_SR_bin_9,nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_jet_energy_res,nom_alpha_jet_energy_scale,nom_alpha_tt_scale_var,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_10,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,obs_x_channel_4j2b_SR,ttbar_norm)
#
# p.d.f.s
# -------
# RooGaussian::alpha_LumiConstraint[ x=alpha_Lumi mean=nom_alpha_Lumi sigma=1 ] = 1
# RooGaussian::alpha_ME_variationConstraint[ x=alpha_ME_variation mean=nom_alpha_ME_variation sigma=1 ] = 1
# RooGaussian::alpha_PS_variationConstraint[ x=alpha_PS_variation mean=nom_alpha_PS_variation sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_1Constraint[ x=alpha_b_tag_NP_1 mean=nom_alpha_b_tag_NP_1 sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_2Constraint[ x=alpha_b_tag_NP_2 mean=nom_alpha_b_tag_NP_2 sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_3Constraint[ x=alpha_b_tag_NP_3 mean=nom_alpha_b_tag_NP_3 sigma=1 ] = 1
# RooGaussian::alpha_b_tag_NP_4Constraint[ x=alpha_b_tag_NP_4 mean=nom_alpha_b_tag_NP_4 sigma=1 ] = 1
# RooGaussian::alpha_jet_energy_resConstraint[ x=alpha_jet_energy_res mean=nom_alpha_jet_energy_res sigma=1 ] = 1
# RooGaussian::alpha_jet_energy_scaleConstraint[ x=alpha_jet_energy_scale mean=nom_alpha_jet_energy_scale sigma=1 ] = 1
# RooGaussian::alpha_tt_scale_varConstraint[ x=alpha_tt_scale_var mean=nom_alpha_tt_scale_var sigma=1 ] = 1
# RooGaussian::alpha_w_plus_jets_scale_varConstraint[ x=alpha_w_plus_jets_scale_var mean=nom_alpha_w_plus_jets_scale_var sigma=1 ] = 1
# RooRealSumPdf::channel_4j2b_SR_model[ ttbar_channel_4j2b_SR_scaleFactors * ttbar_channel_4j2b_SR_shapes + wjets_channel_4j2b_SR_scaleFactors * wjets_channel_4j2b_SR_shapes + single_top_s_channel_4j2b_SR_scaleFactors * single_top_s_channel_4j2b_SR_shapes + single_top_t_channel_4j2b_SR_scaleFactors * single_top_t_channel_4j2b_SR_shapes + single_top_tW_channel_4j2b_SR_scaleFactors * single_top_tW_channel_4j2b_SR_shapes ] = 18.8105/51420.4
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_0_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_0 mean=gamma_stat_channel_4j2b_SR_bin_0 sigma=gamma_stat_channel_4j2b_SR_bin_0_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_10_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_10 mean=gamma_stat_channel_4j2b_SR_bin_10 sigma=gamma_stat_channel_4j2b_SR_bin_10_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_1_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_1 mean=gamma_stat_channel_4j2b_SR_bin_1 sigma=gamma_stat_channel_4j2b_SR_bin_1_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_2_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_2 mean=gamma_stat_channel_4j2b_SR_bin_2 sigma=gamma_stat_channel_4j2b_SR_bin_2_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_3_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_3 mean=gamma_stat_channel_4j2b_SR_bin_3 sigma=gamma_stat_channel_4j2b_SR_bin_3_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_4_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_4 mean=gamma_stat_channel_4j2b_SR_bin_4 sigma=gamma_stat_channel_4j2b_SR_bin_4_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_5_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_5 mean=gamma_stat_channel_4j2b_SR_bin_5 sigma=gamma_stat_channel_4j2b_SR_bin_5_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_6_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_6 mean=gamma_stat_channel_4j2b_SR_bin_6 sigma=gamma_stat_channel_4j2b_SR_bin_6_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_7_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_7 mean=gamma_stat_channel_4j2b_SR_bin_7 sigma=gamma_stat_channel_4j2b_SR_bin_7_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_8_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_8 mean=gamma_stat_channel_4j2b_SR_bin_8 sigma=gamma_stat_channel_4j2b_SR_bin_8_sigma ] = 1
# RooGaussian::gamma_stat_channel_4j2b_SR_bin_9_constraint[ x=nom_gamma_stat_channel_4j2b_SR_bin_9 mean=gamma_stat_channel_4j2b_SR_bin_9 sigma=gamma_stat_channel_4j2b_SR_bin_9_sigma ] = 1
# RooProdPdf::model_channel_4j2b_SR[ alpha_LumiConstraint * alpha_ME_variationConstraint * alpha_PS_variationConstraint * alpha_tt_scale_varConstraint * alpha_jet_energy_scaleConstraint * alpha_jet_energy_resConstraint * alpha_b_tag_NP_1Constraint * alpha_b_tag_NP_2Constraint * alpha_b_tag_NP_3Constraint * alpha_b_tag_NP_4Constraint * alpha_w_plus_jets_scale_varConstraint * gamma_stat_channel_4j2b_SR_bin_0_constraint * gamma_stat_channel_4j2b_SR_bin_1_constraint * gamma_stat_channel_4j2b_SR_bin_2_constraint * gamma_stat_channel_4j2b_SR_bin_3_constraint * gamma_stat_channel_4j2b_SR_bin_4_constraint * gamma_stat_channel_4j2b_SR_bin_5_constraint * gamma_stat_channel_4j2b_SR_bin_6_constraint * gamma_stat_channel_4j2b_SR_bin_7_constraint * gamma_stat_channel_4j2b_SR_bin_8_constraint * gamma_stat_channel_4j2b_SR_bin_9_constraint * gamma_stat_channel_4j2b_SR_bin_10_constraint * channel_4j2b_SR_model(obs_x_channel_4j2b_SR) ] = 18.8105
#
# functions
# --------
# RooBinWidthFunction::channel_4j2b_SR_model_binWidth[ HistFuncForBinWidth=ttbar_channel_4j2b_SR_Hist_alphanominal ] = 0.025
# ParamHistFunc::mc_stat_channel_4j2b_SR[ ] = 1
# PiecewiseInterpolation::single_top_s_channel_4j2b_SR_Hist_alpha[ ] = 0.307327
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_0high[ depList=(obs_x_channel_4j2b_SR) ] = 0.287235
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_0low[ depList=(obs_x_channel_4j2b_SR) ] = 0.327419
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_1high[ depList=(obs_x_channel_4j2b_SR) ] = 0.297961
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_1low[ depList=(obs_x_channel_4j2b_SR) ] = 0.316694
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_2high[ depList=(obs_x_channel_4j2b_SR) ] = 0.337143
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_2low[ depList=(obs_x_channel_4j2b_SR) ] = 0.258769
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_3high[ depList=(obs_x_channel_4j2b_SR) ] = 0.323959
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_3low[ depList=(obs_x_channel_4j2b_SR) ] = 0.284702
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_4high[ depList=(obs_x_channel_4j2b_SR) ] = 0.316477
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_4low[ depList=(obs_x_channel_4j2b_SR) ] = 0.296174
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_5high[ depList=(obs_x_channel_4j2b_SR) ] = 0.312652
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alpha_5low[ depList=(obs_x_channel_4j2b_SR) ] = 0.301217
# RooHistFunc::single_top_s_channel_4j2b_SR_Hist_alphanominal[ depList=(obs_x_channel_4j2b_SR) ] = 0.307327
# RooStats::HistFactory::FlexibleInterpVar::single_top_s_channel_4j2b_SR_epsilon[ paramList=(alpha_Lumi,alpha_jet_energy_scale,alpha_jet_energy_res,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4) ] = 1
# RooProduct::single_top_s_channel_4j2b_SR_scaleFactors[ single_top_s_channel_4j2b_SR_epsilon * Lumi ] = 1
# RooProduct::single_top_s_channel_4j2b_SR_shapes[ single_top_s_channel_4j2b_SR_Hist_alpha * mc_stat_channel_4j2b_SR * channel_4j2b_SR_model_binWidth ] = 0.00768318
# PiecewiseInterpolation::single_top_tW_channel_4j2b_SR_Hist_alpha[ ] = 44.2068
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_0high[ depList=(obs_x_channel_4j2b_SR) ] = 44.1331
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_0low[ depList=(obs_x_channel_4j2b_SR) ] = 44.2805
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_1high[ depList=(obs_x_channel_4j2b_SR) ] = 45.0038
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_1low[ depList=(obs_x_channel_4j2b_SR) ] = 43.4097
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_2high[ depList=(obs_x_channel_4j2b_SR) ] = 50.6787
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_2low[ depList=(obs_x_channel_4j2b_SR) ] = 34.0555
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_3high[ depList=(obs_x_channel_4j2b_SR) ] = 47.3421
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_3low[ depList=(obs_x_channel_4j2b_SR) ] = 40.0284
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_4high[ depList=(obs_x_channel_4j2b_SR) ] = 46.0143
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_4low[ depList=(obs_x_channel_4j2b_SR) ] = 42.0036
# RooHistFunc::single_top_tW_channel_4j2b_SR_Hist_alpha_5high[ depList=(obs_x_channel_4j2b_SR) ] = 45.0526
# ...
# RooDataHist::single_top_t_channel_4j2b_SR_Hist_alpha_3highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_t_channel_4j2b_SR_Hist_alpha_4highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_t_channel_4j2b_SR_Hist_alpha_5highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alphanominalDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_0lowDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_1lowDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_2lowDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_3lowDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_4lowDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_5lowDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_0highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_1highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_2highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_3highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_4highDHist(obs_x_channel_4j2b_SR)
# RooDataHist::single_top_tW_channel_4j2b_SR_Hist_alpha_5highDHist(obs_x_channel_4j2b_SR)
#
# named sets
# ----------
# ModelConfig_GlobalObservables:(nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_10)
# ModelConfig_Observables:(obs_x_channel_4j2b_SR)
# constraintTerms:(alpha_LumiConstraint,alpha_ME_variationConstraint,alpha_PS_variationConstraint,alpha_tt_scale_varConstraint,alpha_jet_energy_scaleConstraint,alpha_jet_energy_resConstraint,alpha_b_tag_NP_1Constraint,alpha_b_tag_NP_2Constraint,alpha_b_tag_NP_3Constraint,alpha_b_tag_NP_4Constraint,alpha_w_plus_jets_scale_varConstraint,gamma_stat_channel_4j2b_SR_bin_0_constraint,gamma_stat_channel_4j2b_SR_bin_1_constraint,gamma_stat_channel_4j2b_SR_bin_2_constraint,gamma_stat_channel_4j2b_SR_bin_3_constraint,gamma_stat_channel_4j2b_SR_bin_4_constraint,gamma_stat_channel_4j2b_SR_bin_5_constraint,gamma_stat_channel_4j2b_SR_bin_6_constraint,gamma_stat_channel_4j2b_SR_bin_7_constraint,gamma_stat_channel_4j2b_SR_bin_8_constraint,gamma_stat_channel_4j2b_SR_bin_9_constraint,gamma_stat_channel_4j2b_SR_bin_10_constraint)
# globalObservables:(nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_10)
# likelihoodTerms:(channel_4j2b_SR_model)
# observables:(obs_x_channel_4j2b_SR)
# observablesSet:(obs_x_channel_4j2b_SR)
#
# generic objects
# ---------------
# RooStats::ModelConfig::ModelConfig
#
# [#2] INFO:HistFactory -- Setting Parameter(s) of Interest as: ttbar_norm
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (obs_x_channel_4j2b_SR)
# Parameters of Interest:  RooArgSet:: = (ttbar_norm)
# Nuisance Parameters:     RooArgSet:: = (alpha_Lumi,alpha_ME_variation,alpha_PS_variation,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4,alpha_jet_energy_res,alpha_jet_energy_scale,alpha_tt_scale_var,alpha_w_plus_jets_scale_var,gamma_stat_channel_4j2b_SR_bin_0,gamma_stat_channel_4j2b_SR_bin_1,gamma_stat_channel_4j2b_SR_bin_10,gamma_stat_channel_4j2b_SR_bin_2,gamma_stat_channel_4j2b_SR_bin_3,gamma_stat_channel_4j2b_SR_bin_4,gamma_stat_channel_4j2b_SR_bin_5,gamma_stat_channel_4j2b_SR_bin_6,gamma_stat_channel_4j2b_SR_bin_7,gamma_stat_channel_4j2b_SR_bin_8,gamma_stat_channel_4j2b_SR_bin_9)
# Global Observables:      RooArgSet:: = (nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_10)
# PDF:                     RooProdPdf::model_channel_4j2b_SR[ alpha_LumiConstraint * alpha_ME_variationConstraint * alpha_PS_variationConstraint * alpha_tt_scale_varConstraint * alpha_jet_energy_scaleConstraint * alpha_jet_energy_resConstraint * alpha_b_tag_NP_1Constraint * alpha_b_tag_NP_2Constraint * alpha_b_tag_NP_3Constraint * alpha_b_tag_NP_4Constraint * alpha_w_plus_jets_scale_varConstraint * gamma_stat_channel_4j2b_SR_bin_0_constraint * gamma_stat_channel_4j2b_SR_bin_1_constraint * gamma_stat_channel_4j2b_SR_bin_2_constraint * gamma_stat_channel_4j2b_SR_bin_3_constraint * gamma_stat_channel_4j2b_SR_bin_4_constraint * gamma_stat_channel_4j2b_SR_bin_5_constraint * gamma_stat_channel_4j2b_SR_bin_6_constraint * gamma_stat_channel_4j2b_SR_bin_7_constraint * gamma_stat_channel_4j2b_SR_bin_8_constraint * gamma_stat_channel_4j2b_SR_bin_9_constraint * gamma_stat_channel_4j2b_SR_bin_10_constraint * channel_4j2b_SR_model(obs_x_channel_4j2b_SR) ] = 18.8105
#
# [#2] INFO:HistFactory -- Opening File to hold channel: _channel_4j2b_SR_meas_model.root
# [#2] INFO:HistFactory -- About to write channel measurement to file
# [#2] PROGRESS:HistFactory -- Writing sample: ttbar
# [#2] PROGRESS:HistFactory -- Writing sample: wjets
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_s
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_t
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_tW
# [#2] PROGRESS:HistFactory -- Saved all histograms
# [#2] PROGRESS:HistFactory -- Saved Measurement
# [#2] PROGRESS:HistFactory -- Successfully wrote channel to file
# [#2] INFO:HistFactory -- full list of observables:
# (obs_x_channel_4j1b_CR,obs_x_channel_4j2b_SR)
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	Entering combination
# -----------------------------------------
#
#
# RooWorkspace(combined) combined contents
#
# variables
# ---------
# (channelCat,nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_jet_energy_res,nom_alpha_jet_energy_scale,nom_alpha_tt_scale_var,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_10,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_10,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,obs_x_channel_4j1b_CR,obs_x_channel_4j2b_SR)
#
# datasets
# --------
# RooDataSet::obsData(obs_x_channel_4j1b_CR,obs_x_channel_4j2b_SR,channelCat)
#
# named sets
# ----------
# ModelConfig_GlobalObservables:(nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j1b_CR_bin_10,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_10)
# ModelConfig_Observables:(obs_x_channel_4j1b_CR,obs_x_channel_4j2b_SR,channelCat)
# globalObservables:(nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j1b_CR_bin_10,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_10)
# observables:(obs_x_channel_4j1b_CR,obs_x_channel_4j2b_SR,channelCat)
#
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	Importing combined model
# -----------------------------------------
#
# [#2] PROGRESS:HistFactory --
# -----------------------------------------
# 	create toy data
# -----------------------------------------
#
# RooDataSet::AsimovData0[obs_x_channel_4j1b_CR,channelCat,weight:binWeightAsimov] = 11 entries (28257.9 weighted)
# RooDataSet::AsimovData1[obs_x_channel_4j2b_SR,channelCat,weight:binWeightAsimov] = 11 entries (51420.4 weighted)
# [#2] INFO:HistFactory -- Setting Parameter(s) of Interest as: ttbar_norm
#
# === Using the following for ModelConfig ===
# Observables:             RooArgSet:: = (obs_x_channel_4j1b_CR,obs_x_channel_4j2b_SR,channelCat)
# Parameters of Interest:  RooArgSet:: = (ttbar_norm)
# Nuisance Parameters:     RooArgSet:: = (alpha_Lumi,alpha_ME_variation,alpha_PS_variation,alpha_b_tag_NP_1,alpha_b_tag_NP_2,alpha_b_tag_NP_3,alpha_b_tag_NP_4,alpha_jet_energy_res,alpha_jet_energy_scale,alpha_tt_scale_var,alpha_w_plus_jets_scale_var,gamma_stat_channel_4j1b_CR_bin_0,gamma_stat_channel_4j1b_CR_bin_1,gamma_stat_channel_4j1b_CR_bin_10,gamma_stat_channel_4j1b_CR_bin_2,gamma_stat_channel_4j1b_CR_bin_3,gamma_stat_channel_4j1b_CR_bin_4,gamma_stat_channel_4j1b_CR_bin_5,gamma_stat_channel_4j1b_CR_bin_6,gamma_stat_channel_4j1b_CR_bin_7,gamma_stat_channel_4j1b_CR_bin_8,gamma_stat_channel_4j1b_CR_bin_9,gamma_stat_channel_4j2b_SR_bin_0,gamma_stat_channel_4j2b_SR_bin_1,gamma_stat_channel_4j2b_SR_bin_10,gamma_stat_channel_4j2b_SR_bin_2,gamma_stat_channel_4j2b_SR_bin_3,gamma_stat_channel_4j2b_SR_bin_4,gamma_stat_channel_4j2b_SR_bin_5,gamma_stat_channel_4j2b_SR_bin_6,gamma_stat_channel_4j2b_SR_bin_7,gamma_stat_channel_4j2b_SR_bin_8,gamma_stat_channel_4j2b_SR_bin_9)
# Global Observables:      RooArgSet:: = (nom_alpha_Lumi,nom_alpha_ME_variation,nom_alpha_PS_variation,nom_alpha_tt_scale_var,nom_alpha_jet_energy_scale,nom_alpha_jet_energy_res,nom_alpha_b_tag_NP_1,nom_alpha_b_tag_NP_2,nom_alpha_b_tag_NP_3,nom_alpha_b_tag_NP_4,nom_alpha_w_plus_jets_scale_var,nom_gamma_stat_channel_4j1b_CR_bin_0,nom_gamma_stat_channel_4j1b_CR_bin_1,nom_gamma_stat_channel_4j1b_CR_bin_2,nom_gamma_stat_channel_4j1b_CR_bin_3,nom_gamma_stat_channel_4j1b_CR_bin_4,nom_gamma_stat_channel_4j1b_CR_bin_5,nom_gamma_stat_channel_4j1b_CR_bin_6,nom_gamma_stat_channel_4j1b_CR_bin_7,nom_gamma_stat_channel_4j1b_CR_bin_8,nom_gamma_stat_channel_4j1b_CR_bin_9,nom_gamma_stat_channel_4j1b_CR_bin_10,nom_gamma_stat_channel_4j2b_SR_bin_0,nom_gamma_stat_channel_4j2b_SR_bin_1,nom_gamma_stat_channel_4j2b_SR_bin_2,nom_gamma_stat_channel_4j2b_SR_bin_3,nom_gamma_stat_channel_4j2b_SR_bin_4,nom_gamma_stat_channel_4j2b_SR_bin_5,nom_gamma_stat_channel_4j2b_SR_bin_6,nom_gamma_stat_channel_4j2b_SR_bin_7,nom_gamma_stat_channel_4j2b_SR_bin_8,nom_gamma_stat_channel_4j2b_SR_bin_9,nom_gamma_stat_channel_4j2b_SR_bin_10)
# PDF:                     RooSimultaneous::simPdf[ indexCat=channelCat channel_4j1b_CR=model_channel_4j1b_CR channel_4j2b_SR=model_channel_4j2b_SR ] = 105.76
#
# [#2] PROGRESS:HistFactory -- Writing combined workspace to file: _combined_meas_model.root
# [#2] PROGRESS:HistFactory -- Writing combined measurement to file: _combined_meas_model.root
# [#2] PROGRESS:HistFactory -- Writing sample: ttbar
# [#2] PROGRESS:HistFactory -- Writing sample: wjets
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_s
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_t
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_tW
# [#2] PROGRESS:HistFactory -- Writing sample: ttbar
# [#2] PROGRESS:HistFactory -- Writing sample: wjets
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_s
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_t
# [#2] PROGRESS:HistFactory -- Writing sample: single_top_tW
# [#2] PROGRESS:HistFactory -- Saved all histograms
# [#2] PROGRESS:HistFactory -- Saved Measurement
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(simPdf) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2
# [#0] WARNING:InputArguments -- RooAbsPdf::fitTo(simPdf): WARNING: a likelihood fit is requested of what appears to be weighted data.
#        While the estimated values of the parameters will always be calculated taking the weights into account,
#        there are multiple ways to estimate the errors of the parameters. You are advised to make an
#        explicit choice for the error calculation:
#            - Either provide SumW2Error(true), to calculate a sum-of-weights-corrected HESSE error matrix
#              (error will be proportional to the number of events in MC).
#            - Or provide SumW2Error(false), to return errors from original HESSE error matrix
#              (which will be proportional to the sum of the weights, i.e., a dataset with <sum of weights> events).
#            - Or provide AsymptoticError(true), to use the asymptotically correct expression
#              (for details see https://arxiv.org/abs/1911.01303)."
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_simPdf_obsData) Summation contains a RooNLLVar, using its error level

# %%
# Print the fit result
result.Print()
# Out:
#   RooFitResult: minimized FCN value: 56216.2, estimated distance to minimum: 0.000164757
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Floating Parameter    FinalValue +/-  Error
#   --------------------  --------------------------
#             alpha_Lumi   -2.4173e-01 +/-  9.77e-01
#     alpha_ME_variation    4.8219e-01 +/-  1.25e-01
#     alpha_PS_variation    4.1771e-01 +/-  1.43e-01
#       alpha_b_tag_NP_1   -6.3189e-02 +/-  5.20e-01
#       alpha_b_tag_NP_2    1.9984e-01 +/-  7.82e-01
#       alpha_b_tag_NP_3   -1.2123e-01 +/-  9.06e-01
#       alpha_b_tag_NP_4   -2.2936e-01 +/-  9.55e-01
#   alpha_jet_energy_res    6.0284e-02 +/-  3.61e-01
#   alpha_jet_energy_scale   -1.1904e-01 +/-  1.76e-01
#     alpha_tt_scale_var    2.0981e-01 +/-  4.01e-01
#   alpha_w_plus_jets_scale_var   -1.3056e-01 +/-  9.87e-01
#   gamma_stat_channel_4j1b_CR_bin_0    1.0112e+00 +/-  9.35e-02
#   gamma_stat_channel_4j1b_CR_bin_1    9.8703e-01 +/-  2.37e-02
#   gamma_stat_channel_4j1b_CR_bin_10    1.0065e+00 +/-  3.21e-02
#   gamma_stat_channel_4j1b_CR_bin_2    9.8674e-01 +/-  1.40e-02
#   gamma_stat_channel_4j1b_CR_bin_3    9.9380e-01 +/-  1.36e-02
#   gamma_stat_channel_4j1b_CR_bin_4    9.9831e-01 +/-  1.40e-02
#   gamma_stat_channel_4j1b_CR_bin_5    9.9951e-01 +/-  1.41e-02
#   gamma_stat_channel_4j1b_CR_bin_6    1.0018e+00 +/-  1.78e-02
#   gamma_stat_channel_4j1b_CR_bin_7    1.0113e+00 +/-  2.31e-02
#   gamma_stat_channel_4j1b_CR_bin_8    1.0051e+00 +/-  2.38e-02
#   gamma_stat_channel_4j1b_CR_bin_9    1.0099e+00 +/-  2.59e-02
#   gamma_stat_channel_4j2b_SR_bin_0    1.0040e+00 +/-  7.88e-03
#   gamma_stat_channel_4j2b_SR_bin_1    9.9973e-01 +/-  5.62e-03
#   gamma_stat_channel_4j2b_SR_bin_10    9.9078e-01 +/-  2.41e-02
#   gamma_stat_channel_4j2b_SR_bin_2    1.0016e+00 +/-  8.17e-03
#   gamma_stat_channel_4j2b_SR_bin_3    9.9939e-01 +/-  9.72e-03
#   gamma_stat_channel_4j2b_SR_bin_4    9.9935e-01 +/-  1.12e-02
#   gamma_stat_channel_4j2b_SR_bin_5    9.9825e-01 +/-  1.34e-02
#   gamma_stat_channel_4j2b_SR_bin_6    9.9692e-01 +/-  1.44e-02
#   gamma_stat_channel_4j2b_SR_bin_7    9.9996e-01 +/-  1.81e-02
#   gamma_stat_channel_4j2b_SR_bin_8    9.9852e-01 +/-  2.07e-02
#   gamma_stat_channel_4j2b_SR_bin_9    9.9746e-01 +/-  2.42e-02
#             ttbar_norm    9.6026e-01 +/-  9.13e-02

# %%
vis = Visualization()
vis.CreateAndSaveResultsPicture("picture.png", ws) # Parameters fit result

vis.DrawCorrelationMatrix("correlation_matrix.png", result) # Correlation matrix
# Out:
# Info in <TCanvas::Print>: png file picture.png has been created
# Info in <TCanvas::Print>: png file correlation_matrix.png has been created

# %%
md = DrawModel(meas, ws)
md.Draw(result)

md.GetChannelPrefitGraph(0).SetTitle("4j1b_CR PREFIT GRAPH") # each graph can be accessed from outside and modified
md.GetChannelPrefitGraph(0).GetYaxis().SetTitle("number of entries")
# Out:
# Info in <TCanvas::Print>: png file channel_4j1b_CR_histo.png has been created
# Info in <TCanvas::Print>: png file channel_4j2b_SR_histo.png has been created

# %%
#save fit results to ROOT file

file = ROOT.TFile("fitResults.root", "RECREATE")

result.Write("fitResult")

file.Close()
